# %%
pip install dataspyre
# Out:
# Collecting dataspyre
#   Downloading DataSpyre-0.2.8.tar.gz (126 kB)
# Requirement already satisfied: six>=1.11.0 in c:\users\home\anaconda3\lib\site-packages (from dataspyre) (1.16.0)
# Requirement already satisfied: numpy in c:\users\home\anaconda3\lib\site-packages (from dataspyre) (1.21.5)
# Requirement already satisfied: pandas in c:\users\home\anaconda3\lib\site-packages (from dataspyre) (1.4.2)
# Collecting cherrypy
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
# Requirement already satisfied: jinja2 in c:\users\home\anaconda3\lib\site-packages (from dataspyre) (2.11.3)
# Requirement already satisfied: matplotlib in c:\users\home\anaconda3\lib\site-packages (from dataspyre) (3.5.1)
# Collecting cheroot>=8.2.1
#   Downloading cheroot-9.0.0-py2.py3-none-any.whl (100 kB)
# Collecting jaraco.collections
#   Downloading jaraco.collections-3.8.0-py3-none-any.whl (10 kB)
# Collecting more-itertools
#   Downloading more_itertools-9.0.0-py3-none-any.whl (52 kB)
# Collecting zc.lockfile
#   Downloading zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting portend>=2.1.1
#   Downloading portend-3.1.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: pywin32>=227 in c:\users\home\anaconda3\lib\site-packages (from cherrypy->dataspyre) (302)
# Collecting jaraco.functools
#   Downloading jaraco.functools-3.5.2-py3-none-any.whl (7.3 kB)
# Collecting tempora>=1.8
#   Downloading tempora-5.2.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: pytz in c:\users\home\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->dataspyre) (2021.3)
# Collecting jaraco.text
#   Downloading jaraco.text-3.11.0-py3-none-any.whl (11 kB)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Collecting inflect
#   Downloading inflect-6.0.2-py3-none-any.whl (34 kB)
# Collecting autocommand
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Collecting jaraco.context>=4.1
#   Downloading jaraco.context-4.2.0-py3-none-any.whl (5.0 kB)
# Collecting pydantic>=1.9.1
#   Downloading pydantic-1.10.4-cp39-cp39-win_amd64.whl (2.1 MB)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\home\anaconda3\lib\site-packages (from jinja2->dataspyre) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\home\anaconda3\lib\site-packages (from matplotlib->dataspyre) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\home\anaconda3\lib\site-packages (from matplotlib->dataspyre) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\home\anaconda3\lib\site-packages (from matplotlib->dataspyre) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\home\anaconda3\lib\site-packages (from matplotlib->dataspyre) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\home\anaconda3\lib\site-packages (from matplotlib->dataspyre) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\home\anaconda3\lib\site-packages (from matplotlib->dataspyre) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\home\anaconda3\lib\site-packages (from matplotlib->dataspyre) (21.3)
# Requirement already satisfied: setuptools in c:\users\home\anaconda3\lib\site-packages (from zc.lockfile->cherrypy->dataspyre) (61.2.0)
# Building wheels for collected packages: dataspyre
#   Building wheel for dataspyre (setup.py): started
#   Building wheel for dataspyre (setup.py): finished with status 'done'
#   Created wheel for dataspyre: filename=DataSpyre-0.2.8-py3-none-any.whl size=126356 sha256=4d8f85a821bfbc5a1611b5499affc0637c3a4a19166d534c83144b7b161eb236
#   Stored in directory: c:\users\home\appdata\local\pip\cache\wheels\5a\03\22\161a2d99a8a24ff21b204f1bb96b6732bf42d6cbf4353fbb0f
# Successfully built dataspyre
# Installing collected packages: typing-extensions, pydantic, more-itertools, jaraco.functools, jaraco.context, inflect, autocommand, tempora, jaraco.text, jaraco.classes, zc.lockfile, portend, jaraco.collections, cheroot, cherrypy, dataspyre
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
# Successfully installed autocommand-2.2.2 cheroot-9.0.0 cherrypy-18.8.0 dataspyre-0.2.8 inflect-6.0.2 jaraco.classes-3.2.3 jaraco.collections-3.8.0 jaraco.context-4.2.0 jaraco.functools-3.5.2 jaraco.text-3.11.0 more-itertools-9.0.0 portend-3.1.0 pydantic-1.10.4 tempora-5.2.0 typing-extensions-4.4.0 zc.lockfile-2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from spyre import server

import pandas as pd
import urllib.request
import urllib.error
import json 

class StockExample(server.App):
    title = "NOAA data  vizualizacion"
    
    inputs = [{   "type":'dropdown',
                  "label": 'Індекс',
                  "options" : [ {"label": "VCI", "value":"VCI"},
                                {"label": "TCI", "value":"TCI"},
                                {"label": "VHI", "value":"VHI"},],
                  "key": 'index',
                  "action_id": "update_data"},
              
              {   "type":'dropdown',
                  "label": 'Область',
                  "options" : [ {"label": "Вінниця", "value":"01"},
                                {"label": "Волинь", "value":"02"},
                                {"label": "Дніпро", "value":"03"},
                                {"label": "Донецьк", "value":"04"},
                                {"label": "Житомир", "value":"05"},
                                {"label": "Закарпаття", "value":"06"},
                                {"label": "Запоріжжя", "value":"07"},
                                {"label": "Франкцівськ", "value":"08"},
                                {"label": "Київ", "value":"09"},
                                {"label": "Кіровоград", "value":"10"},
                                {"label": "Луганськ", "value":"11"},
                                {"label": "Львів", "value":"12"},
                                {"label": "Миколаїв", "value":"13"},
                                {"label": "Одеса", "value":"14"},
                                {"label": "Полтава", "value":"15"},
                                {"label": "Рівне", "value":"16"},
                                {"label": "Суми", "value":"17"},
                                {"label": "Терпнопіль", "value":"18"},
                                {"label": "Харків", "value":"19"},
                                {"label": "Херсон", "value":"20"},
                                {"label": "Проскурів", "value":"21"},
                                {"label": "Черкаси", "value":"22"},
                                {"label": "Чернівці", "value":"23"},
                                {"label": "Чернігів", "value":"24"},
                                {"label": "АРК", "value":"25"},
                                {"label": "Київ місто", "value":"26"},
                                {"label": "Севастополь", "value":"27"}],
                   "key": 'region',
                   "action_id": "update_data"},
              
              {    "input_type":"text",
                   "variable_name":"year",
                   "label":"Рік","value":1981,
                   "key": 'year',
                   "action_id":"update_data"},
              
              {    "type":'slider',
                   "label": 'Перший тиждень',
                   "min" : 1,"max" : 52,"value" : 35,
                   "key": 'first',
                   "action_id": 'update_data'},
              
              {    "type":'slider',
                   "label": 'Останній тиждень',
                   "min" : 1,"max" : 52,"value" : 35,
                   "key": 'last',
                   "action_id": 'update_data'},
              
              {    "type":'slider',
                   "label": 'Відсоток площі',
                   "min" : 0,"max" : 100,"value" : 0,
                   "key": 'percent',
                   "action_id": 'update_data'},
              
              {    "type":'slider',
                   "label": 'Мінімум VHI',
                   "min" : 0,"max" : 100,"value" : 0,
                   "key": 'minimum',
                   "action_id": 'update_data'},
               
              {    "type":'slider',
                    "label": 'Максимум VHI',
                    "min" : 0,"max" : 100,"value" : 100,
                    "key": 'maximum',
                    "action_id": 'update_data'},]
              
    controls = [{    "type" : "hidden",
                    "id" : "update_data"}]

    tabs = ["Plot", "Table"]

    outputs = [{ "type" : "plot",
                    "id" : "plot",
                    "control_id" : "update_data",
                    "tab" : "Plot"},
                { "type" : "table",
                    "id" : "table_id",
                    "control_id" : "update_data",
                    "tab" : "Table",
                    "on_page_load" : True }]

    def getData(self, params):
        index = params['index']
        region = params['region']
        year = params['year']
        first = params['first']
        last = params['last']
        path = 'C:\\Users\\Home\\LabPython\\cleaned\\15_11_2022_14_vhi_id_%02d.csv'.format(region)
        df = pd.read_csv(path, index_col=False, header=9,names=['year', 'week', 'SMN', 'SMT', 'VCI', 'TCI', 'VHI', 'VHI<15', 'VHI<35'])
        df1 = df[(df['year'] == float(year)) & (df['week'] >= float(first)) & (df['week'] <= float(last))]
        df1 = df1[['week', index]]
        return df1

    def getPlot(self, params):
        index = params['index']
        year = params['year']
        first = params['first']
        last = params['last']
        df = self.table(params).set_index('week')
        plt_obj = df.plot()
        plt_obj.set_ylabel(index)
        plt_obj.set_title('Index {index} for {year} from {first} to {last} weeks'.format(index=index,year=float(year), first=float(first), last=float(last)))
        fig = plt_obj.get_figure()
        return fig
    
app = StockExample()
app.launch(port=8080)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 126>()
#     124         return fig
#     125 app = StockExample()
# --> 126 app.launch(port=8080)
#
# File ~\anaconda3\lib\site-packages\spyre\server.py:462, in App.launch(self, host, port, prefix, config)
#     460 def launch(self, host="local", port=8080, prefix='/', config=None):
#     461     self.prefix = prefix
# --> 462     webapp = self.getRoot()
#     463     if host != "local":
#     464         cherrypy.server.socket_host = '0.0.0.0'
#
# File ~\anaconda3\lib\site-packages\spyre\server.py:483, in App.getRoot(self)
#     482 def getRoot(self):
# --> 483     webapp = Root(
#     484         templateVars=self.templateVars,
#     485         title=self.title,
#     486         inputs=self.inputs,
#     487         outputs=self.outputs,
#     488         controls=self.controls,
#     489         tabs=self.tabs,
#     490         spinnerFile=self.spinnerFile,
#     491         getJsonDataFunction=self.getJsonData,
#     492         getDataFunction=self.getData,
#     493         getTableFunction=self.getTable,
#     494         getPlotFunction=self.getPlot,
#     495         getImageFunction=self.getImage,
#     496         getD3Function=self.getD3,
#     497         getCustomJSFunction=self.getCustomJS,
#     498         getCustomCSSFunction=self.getCustomCSS,
#     499         getCustomHeadFunction=self.getCustomHead,
#     500         getHTMLFunction=self.getHTML,
#     501         getDownloadFunction=self.getDownload,
#     502         noOutputFunction=self.noOutput,
#     503         storeUploadFunction=self.storeUpload,
#     504         prefix=self.prefix
#     505     )
#     507     return webapp
#
# File ~\anaconda3\lib\site-packages\spyre\server.py:133, in Root.__init__(self, templateVars, title, inputs, outputs, controls, tabs, spinnerFile, getJsonDataFunction, getDataFunction, getTableFunction, getPlotFunction, getImageFunction, getD3Function, getCustomCSSFunction, getCustomJSFunction, getCustomHeadFunction, getHTMLFunction, getDownloadFunction, noOutputFunction, storeUploadFunction, prefix)
#     130 self.templateVars['custom_css'] = custom_css
#     131 self.templateVars['custom_head'] = custom_head
# --> 133 v = View.View()
#     134 self.templateVars['document_ready_js'] = ""
#     135 self.templateVars['js'] = v.getJS()
#
# File ~\anaconda3\lib\site-packages\spyre\View.py:23, in View.__init__(self)
#      21 self.JS_PATH = os.path.join(self.ROOT_DIR, 'public', 'js')
#      22 self.CSS_PATH = os.path.join(self.ROOT_DIR, 'public', 'css')
# ---> 23 self.APP_PATH = os.path.dirname(os.path.realpath(__main__.__file__))
#
# AttributeError: module '__main__' has no attribute '__file__'
